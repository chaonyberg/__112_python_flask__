# %%
import requests
import pandas as pd
import streamlit as st

#下載U-Bike資料
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
response = requests.request('GET',url)
if response.status_code == 200:
    print("連線成功")
    all_data = response.json()
    print(type(all_data))
else:
    print(f"連線失敗:{response.status_code}")
# Out:
# 連線成功
# <class 'list'>

# %%
#將U-Bike資料轉成dataFrame
dataFrame = pd.DataFrame(data=all_data,columns=['sna','tot','sbi','sarea','mday','ar','bemp','act'])
dataFrame

# %%
#更改欄位名稱(全部更改)
dataFrame.columns = ["站點名稱","車數","可借","行政區","時間","地址","可還","狀態"]

# %%
dataFrame1 = dataFrame.set_index("站點名稱")
dataFrame1
# Out:
#                           車數  可借     行政區                   時間             地址  \
# 站點名稱
# YouBike2.0_捷運科技大樓站        28   8     大安區  2023-06-10 11:54:19    復興南路二段235號前
# YouBike2.0_復興南路二段273號前    21   7     大安區  2023-06-10 11:40:24   復興南路二段273號西側
# YouBike2.0_國北教大實小東側門      16   4     大安區  2023-06-10 11:38:14    和平東路二段96巷7號
# YouBike2.0_和平公園東側         11   2     大安區  2023-06-10 11:44:15  和平東路二段118巷33號
# YouBike2.0_辛亥復興路口西北側      16  16     大安區  2023-06-10 11:49:04     復興南路二段368號
# ...                       ..  ..     ...                  ...            ...
# YouBike2.0_臺大總圖書館西南側      30  15    臺大專區  2023-06-10 11:53:17       臺大圖書館西南側
# YouBike2.0_臺大黑森林西側        20   5    臺大專區  2023-06-10 11:48:17        臺大霖澤館南側
# YouBike2.0_臺大獸醫館南側        24   1    臺大專區  2023-06-10 11:39:04       臺大獸醫系館南側
# YouBike2.0_臺大新體育館東南側      40  15    臺大專區  2023-06-10 11:47:18        臺大體育館東側
# YouBike2.0_臺大明達館北側(員工宿舍)  18   0  臺大公館校區  2023-06-10 10:00:44       明達館北側前空地
#
#                           可還 狀態
# 站點名稱
# YouBike2.0_捷運科技大樓站        20  1
# YouBike2.0_復興南路二段273號前    14  1
# YouBike2.0_國北教大實小東側門      12  1
# YouBike2.0_和平公園東側          9  1
# YouBike2.0_辛亥復興路口西北側       0  1
# ...                       .. ..
# YouBike2.0_臺大總圖書館西南側      15  1
# YouBike2.0_臺大黑森林西側        15  1
# YouBike2.0_臺大獸醫館南側        23  1
# YouBike2.0_臺大新體育館東南側      15  1
# YouBike2.0_臺大明達館北側(員工宿舍)  18  1
#
# [1281 rows x 7 columns]

# %%
dataFrame1['行政區'].drop_duplicates()
# Out:
# 站點名稱
# YouBike2.0_捷運科技大樓站             大安區
# YouBike2.0_延平國宅                大同區
# YouBike2.0_劍潭抽水站               士林區
# YouBike2.0_台北花木批發市場            文山區
# YouBike2.0_臺北自來水事業處            中正區
# YouBike2.0_通北街65巷口             中山區
# YouBike2.0_文湖街21巷118弄口         內湖區
# YouBike2.0_承德路七段304巷口          北投區
# YouBike2.0_捷運松山站(4號出口)         松山區
# YouBike2.0_南港公園(東新街)           南港區
# YouBike2.0_黎忠區民活動中心            信義區
# YouBike2.0_德昌寶興街口(西北角)         萬華區
# YouBike2.0_臺大水源舍區A棟           臺大專區
# YouBike2.0_臺大明達館北側(員工宿舍)    臺大公館校區
# Name: 行政區, dtype: object
